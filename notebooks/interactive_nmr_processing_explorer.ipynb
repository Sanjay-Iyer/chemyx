# %% [markdown]
# # Interactive NMR processing explorer
#
# This notebook is an exploratory, read-only view of the real `chemyx_demo_081026_v3` JCAMP-DX spectra. It reuses the repository's audited production processing functions. Changes made with the controls do **not** alter production CSVs, figures, or either audit package. Optional exports are restricted to the plot-cleanup package's `interactive/exports` directory.
#
# The status line always shows the production settings and whether the current display is `production` or an `exploratory override`.

# %% [markdown]
# ## Launch
#
# From the repository root: `conda activate ai`, then `jupyter lab notebooks/interactive_nmr_processing_explorer.ipynb`. Run the cell below and use the spectrum, phase, reference, baseline, zoom, display, and integration controls.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == 'notebooks':
    repo_root = repo_root.parent
sys.path.insert(0, str(repo_root / 'scripts' / 'nmr'))

from interactive_processing_explorer import create_notebook_explorer

create_notebook_explorer()

# %% [markdown]
# ## Reading the quantitative summary
#
# The live status reports target ppm, Stage-1 variable-width area, fixed 5.70–5.90 ppm area, left-line valley-to-valley area, starting-material area, and silane area. These values are exploratory whenever any control differs from production. Use **Reset to production** before comparing against saved production outputs.
